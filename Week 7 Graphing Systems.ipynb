# %% [markdown]
# # Graphing Systems

# %% [markdown]
# Graph two lines on one graph. Where these two lines cross is the solution.
#
# For example, you have these two equations:
#
# $y = 3x + 10$
#
# $y = 4x$
#
# Estimate. Say you guess that x = 10. Plug x into these equations:
#
# $40 = 3(10) + 10$
#
# $40 = 4(10)$
#
# So 10 works.
#
# Example: use numpy library insteaed of a loop.

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10

# define how many points to plot
points = 10 * (xmax - xmin)

# define the array of x values once
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax],[0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

# line 1
y1 = 2*x
plt.plot(x, y1)

# line 2
y2 = x**2 - 3
plt.plot(x, y2)

plt.show()

# %% [markdown]
# Change the formulas for the lines.

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10

# define how many points to plot
points = 10 * (xmax - xmin)

# define the array of x values once
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax],[0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

# line 1
y1 = -3*x
plt.plot(x, y1)

# line 2
y2 = x**3
plt.plot(x, y2)

plt.show()
