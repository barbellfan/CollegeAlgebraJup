# %% [markdown]
# # Parent Graphs

# %% [markdown]
# A parent graph is the simplest version of a type of graph. Other versions will adjust it one way or the other, like moving the whole thing up or down, or right or left.

# %% [markdown]
# ## Graphs with no slope and no x value
#
# $y = 5$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

plt.plot([xmin, xmax], [5, 5], 'r')

plt.show()

# %% [markdown]
# ## Linear graphs
#
# $y = x$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

plt.plot(x, x, 'r')

plt.show()

# %% [markdown]
# ## Quadratic graphs
#
# $y = x^2$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

plt.plot(x, x**2, 'r')

plt.show()

# %% [markdown]
# ## Cubic graphs
#
# $y = x^3$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

plt.plot(x, x**3, 'r')
#plt.plot(x, x**3 - 2*x**2 - 3*x + 4, 'r')
plt.show()

# %% [markdown]
# ## Quartic graphs
#
# $y = x^4$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

plt.plot(x, x**4, 'r')
plt.show()

# %% [markdown]
# ## Quintic graphs
#
# $y = x^5$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

plt.plot(x, x**5, 'r')
plt.show()

# %% [markdown]
# ## Absolute value graphs
#
# $y = |x|$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

plt.plot(x, abs(x), 'r')
plt.show()

# %% [markdown]
# ## Square root graphs
#
# $y = \sqrt{x}$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(0, xmax, points) # start at zero for square roots

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

plt.plot(x, np.sqrt(x), 'r')
#plt.plot(x, -np.sqrt(x), 'g')
plt.show()

# %% [markdown]
# ## Square root with rational exponent
#
# $y = x^{1/2}$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(0, xmax, points) # start at zero for square roots

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

plt.plot(x, x**(1/2), 'r')

plt.show()

# %% [markdown]
# ## Cube root of x
#
# $y = x^{1/3}$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(xmin, xmax, points) # start at zero for square roots

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

#plt.plot(x, x**(1/3), 'r')
plt.plot(x, np.cbrt(x), 'r') # use numpy

plt.show()

# %% [markdown]
# ## Floor function
#
# $y = \DeclarePairedDelimiter{\floor}{\lfloor}{\rfloor}\floor*{x}$

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 4*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

#plt.plot(x, np.floor(x)) # shows vertical lines between the steps
for x in range(points):
    plt.plot([0.25*x - 10], [math.floor(0.25*x) - 10], 'ro')

plt.show()

# %% [markdown]
# ## Exponential functions
#
# $y = 2^{x}$

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 3*(xmax - xmin)
x = np.linspace(xmin, xmax, points)

fix, ax = plt.subplots()
plt.axis([xmin, xmax, ymin, ymax]) # window size
plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

plt.plot(x, 2**x)

plt.show()

# %% [markdown]
# # Extras

# %% [markdown]
# ## Sliders

# %%
# sliders and zoom
# y = a

# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(a, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10 * (xmax - xmin)
    x = np.linspace(xmin, xmax, points)

    plt.axis([xmin, xmax, ymin, ymax]) # window size
    plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
    plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

    # Line 1
    y1 = a
    y2 = a
    plt.plot([xmin, xmax], [y1, y2])
    plt.show()

interactive_plot = interactive(f, a=(-9, 9), zoom=(1, 100))
interactive_plot

# %%
# sliders and zoom
# y = mx + b

# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(m, b, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10 * (xmax - xmin)
    x = np.linspace(xmin, xmax, points)

    plt.axis([xmin, xmax, ymin, ymax]) # window size
    plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
    plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

    # Line 1
    y1 = m*x + b
    plt.plot(x, y1)
    plt.show()

interactive_plot = interactive(f, m=(-9, 9), b=(-9, 9), zoom=(1, 100))
interactive_plot

# %%
# sliders and zoom
# y = ax**2 + bx + c

# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(a, b, c, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10 * (xmax - xmin)
    x = np.linspace(xmin, xmax, points)

    plt.axis([xmin, xmax, ymin, ymax]) # window size
    plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
    plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

    # Line 1
    y1 = a*x**2 + b*x + c
    plt.plot(x, y1)
    plt.show()

interactive_plot = interactive(f, a=(-9, 9), b=(-9, 9), c=(-9, 9), zoom=(1, 100))
interactive_plot

# %%
# sliders and zoom
# y = abs(x)

# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(a, b, c, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10 * (xmax - xmin)
    x = np.linspace(xmin, xmax, points)

    plt.axis([xmin, xmax, ymin, ymax]) # window size
    plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
    plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

    # Line 1
    y1 = a*abs(x-b) + c
    plt.plot(x, y1)
    plt.show()

interactive_plot = interactive(f, a=(-9, 9), b=(-9, 9), c=(-9, 9), zoom=(1, 100))
interactive_plot

# %%
# sliders and zoom
# y = sqrt(x)

# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(a, b, c, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10 * (xmax - xmin)
    x = np.linspace(xmin, xmax, points)

    plt.axis([xmin, xmax, ymin, ymax]) # window size
    plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
    plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

    # Line 1
    y1 = a*np.sqrt(x-b) + c
    plt.plot(x, y1)
    plt.show()

interactive_plot = interactive(f, a=(-9, 9), b=(-9, 9), c=(-9, 9), zoom=(1, 100))
interactive_plot
# Out:
# /tmp/ipykernel_19286/599828381.py:23: RuntimeWarning: invalid value encountered in sqrt
#   y1 = a*np.sqrt(x-b) + c

# %%
# sliders and zoom
# y = x**3 + ...

# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(a, b, c, d, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10 * (xmax - xmin)
    x = np.linspace(xmin, xmax, points)

    plt.axis([xmin, xmax, ymin, ymax]) # window size
    plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
    plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

    # Line 1
    y1 = a*x**3 + b*x**2 + c*x + d
    plt.plot(x, y1)
    plt.show()

interactive_plot = interactive(f, a=(-9, 9), b=(-9, 9), c=(-9, 9), d=(-9, 9), zoom=(1, 100))
interactive_plot

# %%
# sliders and zoom
# y = x**4 + ...

# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(a, b, c, d, e, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10 * (xmax - xmin)
    x = np.linspace(xmin, xmax, points)

    plt.axis([xmin, xmax, ymin, ymax]) # window size
    plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
    plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

    # Line 1
    y1 = a*x**4 + b*x**3 + c*x**2 + d*x + e
    plt.plot(x, y1)
    plt.show()

interactive_plot = interactive(f, a=(-9, 9), b=(-9, 9), c=(-9, 9), d=(-9, 9), e=(-9, 9), zoom=(1, 100))
interactive_plot

# %%
# sliders and zoom
# y = np.floor(x)

# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(a, b, c, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10 * (xmax - xmin)
    x = np.linspace(xmin, xmax, points)

    plt.axis([xmin, xmax, ymin, ymax]) # window size
    plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
    plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

    # Line 1
    y1 = a*np.floor(x-b) + c
    plt.plot(x, y1, 'ro')
    plt.show()

interactive_plot = interactive(f, a=(-9, 9), b=(-9, 9), c=(-9, 9), zoom=(1, 100))
interactive_plot

# %%
# sliders and zoom
# y = a*b**(cx-d) + e

# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(a, b, c, d, e, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10 * (xmax - xmin)
    x = np.linspace(xmin, xmax, points)

    plt.axis([xmin, xmax, ymin, ymax]) # window size
    plt.plot([xmin, xmax], [0, 0], 'b') # blue x axis
    plt.plot([0, 0], [ymin, ymax], 'b') # blue y axis

    # Line 1
    y1 = a*b**(c*x-d) + e
    plt.plot(x, y1)
    plt.show()

interactive_plot = interactive(f, a=(-9, 9), b=(-9, 9), c=(-9, 9), d=(-9, 9), e=(-9, 9), zoom=(1, 100))
interactive_plot
