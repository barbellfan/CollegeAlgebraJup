# %% [markdown]
# # Four ways to solve for an unknown number
# $ x + 3 = 5 $
#
# $   -3  -3$
#
# $ x = 2$
# <hr>
# $ x - 2 = 10 $
#
# $ +2 +2 $
#
# $ x = 12 $
# <hr>
# $ 3x = 12 $
#
# $ \div 3  \div 3 $
#
# $ x = 4 $
# <hr>
# $ \frac{x}{4} = 2 $
#
# $ *4 *4 $
#
# $ x = 8 $

# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

# Put the equation here
eq = x - 2
print("x = ", solve(eq, x))

eq = x**2 - 4
print("x = ", solve(eq, x))

eq = 2*x - 4
print("x = ", solve(eq, x))

# %% [markdown]
# # Extra problems

# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

# Put the equation here
eq = 2*x**2 + 1
print("x = ", solve(eq, x))

eq = 2*x**2 - 4
print("x = ", solve(eq, x))

# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')
eq = input('Enter equation: 0 = ')

print("x = ", solve(eq, x))

# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

eq = 2*x - 4

solution = solve(eq,x)
print("x = ", solution [0])

# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

# two different ways to get the equation
eq = input("enter equation: 0 = ")
# sample equation: (x-1)*(x+2)*(x-3)

solution = solve(eq,x)
for s in solution:
  print("x = ", s)

# %%
from sympy import *

x, y = var('x y')

# first equation set equal to zero, ready to solve
first = 2*x + 10

#Sympy syntax for equation equal to y, ready to factor
eq1 = Eq(first, y)

# Sympy solve for x
sol = solve(eq1, x)

# show factored results
print("x = ", sol[0])

# %% [markdown]
# # Factoring

# %%
import sympy
from sympy import symbols

x, y = var('x y')

#eq = 2*x + 10*y + 4
#eq = x**2 - 4
eq = x**3 - 2*x**2 - 5*x + 6

print(sympy.factor(eq))

# %% [markdown]
# # Explaining how each function works

# %%
# converts string input (including fractions) to float
def string_frac(in_string):
  if "/" in in_string:
    nd = in_string.split("/")
    n = float(nd[0])
    d = float(nd[1])
    ans = n/d
    return ans
  else:
    ans = float(in_string)
    return ans

#simplest one-step addition
def one_step_add():
  import random
  # display problem
  a = random.randint(-4,10)
  b = random.randint(2,24)
  print("x + ", a, " = ", b)
  ans = float(input("x = "))
  answer = b-a
  if ans== answer:
    print("Correct! \n")
  else:
    print("Try again")
    print("The correct answer is ", answer, "\n")

# ib-step addition with negative numbers
def one_step_subtract():
  import random
  a = random.randint(-19,-1)
  b = random.randint(2,24)
  print(a, " + x = ", b)
  ans = float(input("x = "))
  answer = b - a
  if ans==answer:
    print("Correct! \n")
  else:
    print("Try again")
    print("The correct answer is ", answer, "\n")

# one-step multiply
def one_step_mult():
  # uses string_frac(<input string>)
  import random
  a = random.randint(1,11)
  b = random.randint(2,24)
  print(a, "x = ", b)
  ans_in = (input("x = "))
  answer = b/a
  if string_frac(ans_in) == answer:
    print("Correct! \n")
  else:
    print("Try again \n")
    print("The correct answer is ", answer, "\n")

def main():
  one_step_mult()

if __name__ == "__main__":
  main()

# %% [markdown]
# # Factoring and solving for a variable

# %%
from sympy import *
import math

# Identify all variables
a, b, c, d, x = var('a b c d x')

# Left and rights sides of the equal sign
left = 0
right = a*x**2 + b*x + c

# Variable to solve for
variable = x

# Sympy equation left = right
eq1 = Eq(left, right)

# Sympy solve for that variable
sol = solve(eq1, variable)

# Show factored results
for s in sol:
  print(variable, " = ", s)
